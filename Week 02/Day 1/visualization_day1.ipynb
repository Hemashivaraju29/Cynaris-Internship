# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../../Week 01/Day 5/sales_cleaned.csv")

print("Sales Data:")
display(df)
# Out:
# Sales Data:
#    sale_id customer_name product     category  quantity   amount       city  \
# 0        1          Anil  Laptop  Electronics         1  55000.0  Bengaluru
# 1        4        Ananya  Laptop  Electronics         1  65000.0      Delhi
# 2        9         Divya  Laptop  Electronics         1  75000.0  Bengaluru
#
#   payment_method
# 0            UPI
# 1            UPI
# 2            UPI

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\hemas\OneDrive\Pictures\Documents\Cynaris-Internship\Week 02\Day 1

# %%
sns.set_theme(style="whitegrid")

print("Seaborn theme applied successfully!")
# Out:
# Seaborn theme applied successfully!

# %%
plt.figure(figsize=(8, 5))

plt.plot(
    df["sale_id"],
    df["amount"],
    marker="o",
    linewidth=2
)

plt.title("Sales Amount by Sale ID")
plt.xlabel("Sale ID")
plt.ylabel("Sales Amount")

# Add data callouts
for x, y in zip(df["sale_id"], df["amount"]):
    plt.annotate(
        f"₹{y:,.0f}",
        (x, y),
        textcoords="offset points",
        xytext=(0, 8),
        ha="center"
    )

plt.tight_layout()
plt.show()

# %%
# Bar Chart - Total Sales by Category

category_sales = df.groupby(
    "category",
    as_index=False
)["amount"].sum()

plt.figure(figsize=(8, 5))

ax = sns.barplot(
    data=category_sales,
    x="category",
    y="amount"
)

plt.title("Total Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")

# Add data callout
for container in ax.containers:
    ax.bar_label(
        container,
        labels=[f"₹{value:,.0f}" for value in container.datavalues]
    )

plt.tight_layout()
plt.show()

# %%
# Scatter Plot - Quantity vs Sales Amount

plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x="quantity",
    y="amount",
    hue="category",
    s=120
)

plt.title("Quantity vs Sales Amount")
plt.xlabel("Quantity")
plt.ylabel("Sales Amount")

plt.tight_layout()
plt.show()

# %%
# Histogram - Distribution of Sales Amount

plt.figure(figsize=(8, 5))

sns.histplot(
    data=df,
    x="amount",
    bins=5,
    kde=True
)

plt.title("Distribution of Sales Amount")
plt.xlabel("Sales Amount")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
# Box Plot - Sales Amount by Category

plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="category",
    y="amount"
)

plt.title("Sales Amount by Category")
plt.xlabel("Category")
plt.ylabel("Sales Amount")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Chart Files
#
# The following visualizations were created and saved as PNG files:
#
# 1. Line Chart
# 2. Bar Chart
# 3. Scatter Plot
# 4. Histogram
# 5. Box Plot
